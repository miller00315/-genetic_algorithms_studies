# %% [markdown]
# <a href="https://colab.research.google.com/github/miller00315/-genetic_algorithms_studies/blob/main/text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
from gtts import gTTS

text_to_say = 'How are you?'

language = 'en'

gtts_object = gTTS(
    text=text_to_say,
    lang=language,
    slow=False
)

gtts_object.save('how_are_you.mp3')

# %%
from IPython.display import Audio
